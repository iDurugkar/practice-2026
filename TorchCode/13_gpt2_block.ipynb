# %% [markdown]
# <a href="https://colab.research.google.com/github/iDurugkar/practice-2026/blob/main/TorchCode/13_gpt2_block.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/13_gpt2_block.ipynb)
#
# # 🔴 Hard: GPT-2 Transformer Block
#
# Implement a full **GPT-2 style Transformer block** — combining everything you've learned.
#
# ### Architecture (Pre-Norm)
# ```
# x = x + causal_self_attention(ln1(x))
# x = x + mlp(ln2(x))
# ```
#
# ### Signature
# ```python
# class GPT2Block(nn.Module):
#     def __init__(self, d_model: int, num_heads: int): ...
#     def forward(self, x: torch.Tensor) -> torch.Tensor: ...
# ```
#
# ### Requirements
# - Inherit from `nn.Module`
# - `self.ln1`, `self.ln2`: `nn.LayerNorm(d_model)`
# - `self.W_q`, `self.W_k`, `self.W_v`, `self.W_o`: `nn.Linear` for attention
# - `self.mlp`: `nn.Sequential(Linear(d, 4d), GELU(), Linear(4d, d))`
# - Attention must be **causal** (mask future positions)
# - Pre-norm architecture (LayerNorm *before* attention and MLP)
# - Residual connections around both attention and MLP

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 1.3 MB/s eta 0:00:00

# %%
import torch
import torch.nn as nn
import math

# %%
# ✏️ YOUR IMPLEMENTATION HERE

class GPT2Block(nn.Module):
    def __init__(self, d_model, num_heads):
        super().__init__()
        # Initialize layers
        self.d_model = d_model
        self.num_heads = num_heads
        self.d_k = d_model // num_heads
        self.W_q = nn.Linear(d_model, d_model)
        self.W_k = nn.Linear(d_model, d_model)
        self.W_v = nn.Linear(d_model, d_model)
        self.W_o = nn.Linear(d_model, d_model)

        self.ln1 = nn.LayerNorm((d_model,))

        self.mlp = nn.Sequential(
            nn.Linear(d_model, 4 * d_model),
            nn.GELU(),
            nn.Linear(4 * d_model, d_model)
            )
        self.ln2 = nn.LayerNorm((d_model,))

    def _causal_self_attention(self, x):
        B, S, d_model = x.shape
        q = self.W_q(x).view(B, S, self.num_heads, self.d_k).transpose(1, 2)
        k = self.W_k(x).view(B, S, self.num_heads, self.d_k).transpose(1, 2)
        v = self.W_v(x).view(B, S, self.num_heads, self.d_k).transpose(1, 2)

        scores = torch.matmul(q, k.transpose(-1, -2)) / math.sqrt(self.d_k)
        # causal masking
        mask = torch.triu(torch.ones_like(scores, dtype=torch.bool), diagonal=1)
        scores = torch.masked_fill(scores, mask, float('-inf'))
        # attention
        weights = torch.softmax(scores, dim=-1)
        res = torch.matmul(weights, v)
        return self.W_o(res.transpose(1, 2).contiguous().view(B, S, d_model))

    def forward(self, x):
        # Pre-norm + causal attention + MLP with residuals
        x = x + self._causal_self_attention(self.ln1(x))
        x = x + self.mlp(self.ln2(x))
        return x

# %%
# 🧪 Debug
torch.manual_seed(0)
block = GPT2Block(d_model=64, num_heads=4)
x = torch.randn(2, 8, 64)
out = block(x)
print("Output shape:", out.shape)           # (2, 8, 64)
print("Is nn.Module?", isinstance(block, nn.Module))
print("Params:", sum(p.numel() for p in block.parameters()))
# Out:
# Output shape: torch.Size([2, 8, 64])
# Is nn.Module? True
# Params: 49984

# %%
from torch_judge import check
check('gpt2_block')
# Out:
# 🧪 Testing: GPT-2 Transformer Block (Hard)
# ──────────────────────────────────────────────────
#   ✅ [1/5] Output shape (8.4ms)
#   ✅ [2/5] Has LayerNorm (pre-norm architecture) (1.2ms)
#   ✅ [3/5] MLP has 4x expansion with GELU (1.1ms)
#   ✅ [4/5] Causal masking — future doesn't affect past (3.4ms)
#   ✅ [5/5] Gradient flow to all parameters (3.7ms)
# ──────────────────────────────────────────────────
#   🎉 All 5 tests passed! (17.8ms total)
#   Progress saved. Run status() to see your dashboard.
